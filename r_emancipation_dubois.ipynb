# %% [markdown]
# # Visualizing Black Emancipation Over Time
#
# <div>
# <img src="https://github.com/ajstarks/dubois-data-portraits/raw/master/dubois-stem/original-plate-51.jpg" width="300" />
# </div>

# %% [markdown]
# ### In this interactive excercise, you will:
#
# 1. Learn how to create a variation of a **time series line graph** known as a stacked area graph.
# 2. You will do so by learning and modifying code in the statistical programming lanugage *R*.
#
# ### You will learn how to use the *R* statistical programming language by creating two graphs:
#
# 1. You will recreate Du Bois' visualization of Black emancipation shown above that plots the free and enslaved status of Black people in the US over time. Du Bois created the visualization in 1900.
#
# 2. You will reproduce Du Bois' visualization using data on Black educational attainment over time. This aligns with how Du Bois saw mass education as one important strategy for furthering and deepining emancipation for Black Americans and others.

# %% [markdown]
# ### This interactive webpage is called a **Jupyter Notebook**. Grey cells in the *Notebook* like the one below are **code cells** where you will write and edit **R** Code. To try it out:
# 1. Click your cursor on the grey cell below. After you click on it, it will change to white to indicate you are editing it.
# 2. After you clickg on the cell below and it turns white. Type ```2+2``` to use R as a calculator.
# 3. After typing ```2+2```, click the *play button* triangle that points to the right at the top of this page.

# %% [markdown]
# ### Sometimes, the code cells will already have code in them that you will be asked to edit or run by clicking the play button. In the process, you can click on ```...``` buttons like the ones below to get hints and answers. For example:
# 1. Click on the cell below with ```3+3=``` and click the play triangle above. You should get an error message highlighted in pink the begins "Error in parse...". To complete this activity, you'll want to get each code cell to run without a pink error message.
# 2. Based on the ```2+2``` code you tried above, try to edit the ```3+3=``` code to get it to report the sum of 3+3 without the error message. For a hint, click the first ```...``` buttown below.

# %% [markdown]
# **Hint:** Try deleting the ```=``` sign in the cell and click play again. If that doesn't work, click the next ```...``` button below for the answer.

# %% [markdown]
# **Answer:** Delete all the text in the cell below and write or paste this answer in the cell: ```3+3``` before clicking play again.

# %%
3+3=

# %%
#load packages
#library(conflicted)  
#library(tidyverse)
#library(extrafont)
library(ggplot2)

# %%
d_emancipation_dubois <- read.csv("data/d2_emancipation_dubois.csv")

# %%
d_emancipation_dubois
# Out:
#   year percent label
# 1 1790 92.0    8%
# 2 1800 88.0    12%
# 3 1810 86.5    13.50%
# 4 1820 87.0    13%
# 5 1830 86.0    14%
# 6 1840 87.0    13%
# 7 1850 88.0    12%
# 8 1860 89.0    11%
# 9 1870  0.0

# %%
ggplot(d_emancipation_dubois,
    aes(x = year, y = percent)
       ) +
    geom_line()
# Out:
# plot without title

# %%
ggplot(d_emancipation_dubois,
    aes(x = year, y = percent)
       ) +
    geom_area()
# Out:
# plot without title

# %%
ggplot(d_emancipation_dubois,
    aes(
    x = year,
    y = percent
  )
) +
geom_area(aes(y = 100),
    fill = "darkgreen"
  ) +
  geom_area(fill = "gray15")
# Out:
# plot without title

# %%
ggplot(d_emancipation_dubois,
    aes(
    x = year,
    y = percent
  )
) +
geom_area(aes(y = 100),
    fill = "darkgreen"
  ) +
  geom_area(fill = "gray15") +
  scale_x_continuous(
    breaks = seq(1790, 1870, by = 10),
    position = "top"
  ) +
  coord_cartesian(
    expand = FALSE,
    clip = "off",
    xlim = c(1788, 1872)
  ) +
   geom_text(
  aes(
    y = percent +2,
    label = paste0(label),
    fontface = "bold"
  ),
  nudge_y = 0.02
)
# Out:
# plot without title

# %%
 theme(
      plot.background = element_rect(
        fill = "antiquewhite2",
        color = "antiquewhite2"
      ),
      panel.background = element_rect(
        fill = "antiquewhite2",
        color = "antiquewhite2"
      ),
      plot.title = element_text(
        hjust = 0.5,
        face = "bold"
      ),
      plot.subtitle = element_text(hjust = 0.5)
    )

# %%
+
  scale_x_continuous(
    breaks = seq(1790, 1870, by = 10),
    position = "top"
  )

# %%
ggplot(d_emancipation_dubois,
    aes(
    x = year,
    y = percent
  )
) +
geom_area(aes(y = 100),
    fill = "darkgreen"
  ) +
  geom_area(fill = "gray15")

# %%
ggplot(subset(d_emancipation_dubois, status=="Slave"), aes(x = year, y = percent, group(status))) +
    geom_line()
# Out:
# plot without title

# %%
ggplot(d_emancipation_dubois, aes(x = year, y = percent, fill = status)) +
      geom_area()
# Out:
# plot without title

# %%
freemen <- data.frame(
  year = seq(1790, 1870, by = 10),
  pct_free = c(0.08, 0.11, 0.135, 0.13, 0.14, 0.13, 0.12, 0.11, 1)
) %>%
# Out:
# Error in parse(text = input): <text>:5:0: unexpected end of input
# 3:   pct_free = c(0.08, 0.11, 0.135, 0.13, 0.14, 0.13, 0.12, 0.11, 1)
# 4: ) %>%
#   ^
# Traceback:

# %%
ggplot(
  data = freemen,
  mapping = aes(
    x = year,
    y = pct_slave
  )
) +
  geom_area(aes(y = 1),
    fill = "seagreen"
  ) +
  geom_area(fill = "gray15")

# %%
ggplot(d_emancipation_dubois, aes(x = year, y = percent, fill = status)) +
  geom_area() +
    scale_fill_manual(values = c("darkgreen", "black"))
# Out:
# plot without title

# %%
ggplot(d_emancipation_dubois, aes(x = year, y = percent, fill = status))  +
  geom_area() +
    scale_fill_manual(values = c("darkgreen", "black")) +
  annotate(
    "text",
    label = c("SLAVES\nESCLAVES", "FREE - LIBRE"),
    color = c("antiquewhite", "black"),
    size = c(9, 6),
    x = 1830,
    y = c(50, 97),
    fontface = "bold"
  ) + 
geom_text(
  aes(
    y = percent+2,
    label = paste0(label),
    fontface = "bold"
  ),
  nudge_y = 0.02
) +
  labs(
    title = "PROPORTION OF FREEMEN AND SLAVES AMONG AMERICAN NEGROES.\nPROPORTION DES NÈGRES LIBRES ET DES ESCLAVES EN AMÉRIQUE.",
    subtitle = "DONE BY ATLANTA UNIVERSITY."
  )
# Out:
# plot without title

# %%
ggplot(d_emancipation_dubois, aes(x = year, y = percent, fill = status))  +
  geom_area() +
    scale_fill_manual(values = c("darkgreen", "black")) +
  annotate(
    "text",
    label = c("SLAVES\nESCLAVES", "FREE - LIBRE"),
    color = c("antiquewhite", "black"),
    size = c(9, 6),
    x = 1830,
    y = c(50, 97),
    fontface = "bold"
  ) + 
geom_text(
  aes(
    y = percent+2,
    label = paste0(label),
    fontface = "bold"
  ),
  nudge_y = 0.02
) + 
theme_void()+
  labs(title = "PROPORTION OF FREEMEN AND SLAVES AMONG AMERICAN NEGROES .\nPROPORTION DES NÈGRES LIBRES ET DES ESCLAVES EN AMÉRIQUE.\n",
       subtitle = "DONE BY ATLANTA UNIVERSITY.\n",
       )+
  theme(plot.title = element_text(hjust=0.5,size = 18,family="mono",colour = "black", face = "bold"),
        plot.caption = element_text(hjust=0.5,family="mono",face="bold",size = 14, colour = "black"),
        plot.subtitle = element_text(hjust=0.5,family="mono",face="bold",size = 18, colour = "black"),
        plot.background = element_rect(fill = 'papayawhip'),
        legend.position = "none")
# Out:
# plot without title

# %%
ggplot(d_emancipation_dubois, aes(x = year, y = percent, fill = status))  +
  geom_area() +
    scale_fill_manual(values = c("darkgreen", "black")) +
  annotate(
    "text",
    label = c("SLAVES\nESCLAVES", "FREE - LIBRE"),
    color = c("antiquewhite", "black"),
    size = c(9, 6),
    x = 1830,
    y = c(50, 97),
    fontface = "bold"
  ) + 
geom_text(
  aes(
    y = percent+2,
    label = paste0(label),
    fontface = "bold"
  ),
  nudge_y = 0.02
) +
theme_void()+
 labs(title = "PROPORTION OF FREEMEN AND SLAVES AMONG AMERICAN NEGROES .\nPROPORTION DES NÈGRES LIBRES ET DES ESCLAVES EN AMÉRIQUE.\n",
       subtitle = "DONE BY ATLANTA UNIVERSITY.\n") +
  ### theme adjustments
    theme(
      plot.background = element_rect(
        fill = "antiquewhite2",
        color = "antiquewhite2"
      ),
      panel.background = element_rect(
        fill = "antiquewhite2",
        color = "antiquewhite2"
      ),
      plot.title = element_text(
        hjust = 0.5,
        face = "bold"
      ),
      plot.subtitle = element_text(
          hjust = 0.5,
        face = "bold"
      ),
    panel.grid.major.x = element_line(color = "gray25"),
    panel.grid.minor = element_blank(),
    panel.grid.major.y = element_blank(),
    axis.text.y = element_blank(),
    axis.ticks = element_blank(),
    axis.title = element_blank()
    )
# Out:
# plot without title

# %%
ggplot(d_emancipation_dubois, aes(x = year, y = percent, fill = status))  +
  geom_area() +
    scale_fill_manual(values = c("darkgreen", "black")) +
  annotate(
    "text",
    label = c("SLAVES\nESCLAVES", "FREE - LIBRE"),
    color = c("antiquewhite", "black"),
    size = c(9, 6),
    x = 1830,
    y = c(50, 97),
    fontface = "bold"
  ) + 
geom_text(
  aes(
    y = percent+2,
    label = paste0(label),
    fontface = "bold"
  ),
  nudge_y = 0.02
) +
  ### theme adjustments
    theme(
      plot.background = element_rect(
        fill = "antiquewhite2",
        color = "antiquewhite2"
      ),
      panel.background = element_rect(
        fill = "antiquewhite2",
        color = "antiquewhite2"
      ),
      plot.title = element_text(
        hjust = 0.5,
        face = "bold"
      ),
      plot.subtitle = element_text(hjust = 0.5)
            text = element_text(face = "bold"),
    panel.background = element_blank(),
    plot.subtitle = element_text(size = 7),
    panel.grid.major.x = element_line(color = "gray25"),
    panel.grid.minor = element_blank(),
    panel.grid.major.y = element_blank(),
    axis.text.y = element_blank(),
    axis.ticks = element_blank(),
    axis.title = element_blank()
    )
# Out:
# Error in parse(text = input): <text>:36:13: unexpected symbol
# 35:       plot.subtitle = element_text(hjust = 0.5)
# 36:             text
#                 ^
# Traceback:

# %%
    theme(
      plot.background = element_rect(
        fill = "antiquewhite2",
        color = "antiquewhite2"
      ),
      panel.background = element_rect(
        fill = "antiquewhite2",
        color = "antiquewhite2"
      ),
      plot.title = element_text(
        hjust = 0.5,
        face = "bold"
      ),
      plot.subtitle = element_text(hjust = 0.5)
    )

  theme(
    text = element_text(face = "bold"),
    panel.background = element_blank(),
    plot.subtitle = element_text(size = 7),
    panel.grid.major.x = element_line(color = "gray25"),
    panel.grid.minor = element_blank(),
    panel.grid.major.y = element_blank(),
    axis.text.y = element_blank(),
    axis.ticks = element_blank(),
    axis.title = element_blank()
  )
